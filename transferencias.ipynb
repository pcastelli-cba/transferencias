# %%
import pandas as pd
import os
from google.colab import drive
#drive.mount('/content/gdrive')
#%cd '/content/gdrive/MyDrive/transferencias/'


df = pd.read_csv('dnrpa-transferencias-autos-202112.csv', index_col=0)
df
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (8) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                         tramite_fecha fecha_inscripcion_inicial  \
# tramite_tipo
# TRANSFERENCIA IMPORTADO    2021-12-14                2017-01-19
# TRANSFERENCIA IMPORTADO    2021-12-07                2018-08-14
# TRANSFERENCIA IMPORTADO    2021-12-17                2016-11-18
# TRANSFERENCIA IMPORTADO    2021-12-10                2020-08-06
# TRANSFERENCIA IMPORTADO    2021-12-16                2008-01-11
# ...                               ...                       ...
# TRANSFERENCIA NACIONAL     2021-12-21                2013-10-24
# TRANSFERENCIA NACIONAL     2021-12-02                1970-03-18
# TRANSFERENCIA NACIONAL     2021-12-14                1971-01-29
# TRANSFERENCIA NACIONAL     2021-12-17                1971-10-20
# ...

# %%
import missingno as msno
# %matplotlib inline
msno.matrix(df)

# %%
df.head()
# Out:
#                         tramite_fecha fecha_inscripcion_inicial  \
# tramite_tipo
# TRANSFERENCIA IMPORTADO    2021-12-14                2017-01-19
# TRANSFERENCIA IMPORTADO    2021-12-07                2018-08-14
# TRANSFERENCIA IMPORTADO    2021-12-17                2016-11-18
# TRANSFERENCIA IMPORTADO    2021-12-10                2020-08-06
# TRANSFERENCIA IMPORTADO    2021-12-16                2008-01-11
#
#                          registro_seccional_codigo  \
# tramite_tipo
# TRANSFERENCIA IMPORTADO                      21056
# TRANSFERENCIA IMPORTADO                      21052
# TRANSFERENCIA IMPORTADO                      21056
# TRANSFERENCIA IMPORTADO                      21048
# TRANSFERENCIA IMPORTADO                      21049
#
#                         registro_seccional_descripcion  \
# tramite_tipo
# TRANSFERENCIA IMPORTADO                  ROSARIO Nº 13
# TRANSFERENCIA IMPORTADO                   RAFAELA Nº 4
# TRANSFERENCIA IMPORTADO                  ROSARIO Nº 13
# ...

# %%
df.describe()
# Out:
#        registro_seccional_codigo  automotor_anio_modelo  automotor_uso_codigo  \
# count              150366.000000          149209.000000         150359.000000
# mean                 7295.372923            2007.586808              1.011858
# std                  7510.883956              29.474540              0.261450
# min                  1001.000000              20.000000              0.000000
# 25%                  1218.000000            2005.000000              1.000000
# 50%                  4018.000000            2011.000000              1.000000
# 75%                 13027.000000            2015.000000              1.000000
# max                 24008.000000            2022.000000              9.000000
#
#        titular_anio_nacimiento  titular_porcentaje_titularidad  \
# count            150363.000000                   150366.000000
# mean               1981.161882                       97.172359
# std                  17.396320                       11.729098
# ...
